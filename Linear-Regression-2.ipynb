# %% [markdown]
# # Linear Regression Implementation
#
# ## Doesnt involve any predictions, just understanding how to calculate the variance, covariance and coefficients

# %%
from IPython.display import Image
Image(filename='ols.png')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### A linear regression model can be defined as:

# %%
y = b0 + (b1 * X)

# %% [markdown]
# ### We can estimate the coefficients as follows:

# %%
def coefficients(self, X, y, i):
    b1 = sum((X(i)-np.mean(X)) * (y(i)-np.mean(y))) /  sum((X(i) - np.mean(X))**2)
    b0 = np.mean(y) - (b1*np.mean(X))
    return b1, b0

# %%
from sklearn import datasets

# import some data 
iris = datasets.load_iris()
X = iris.data[:, :1]  # x is 1st colum -- Sepal Length
y = iris.data[:, 1:2] # y is 2nd column -- Sepal Width

# %%
print(X.shape)
# Out:
# (150, 1)

# %%
print(X)
# Out:
# [[5.1]
#  [4.9]
#  [4.7]
#  [4.6]
#  [5. ]
#  [5.4]
#  [4.6]
#  [5. ]
#  [4.4]
#  [4.9]
#  [5.4]
#  [4.8]
#  [4.8]
#  [4.3]
#  [5.8]
#  [5.7]
#  [5.4]
#  [5.1]
#  [5.7]
#  [5.1]
#  [5.4]
#  [5.1]
#  [4.6]
#  [5.1]
#  [4.8]
#  [5. ]
#  [5. ]
#  [5.2]
#  [5.2]
#  [4.7]
#  [4.8]
#  [5.4]
#  [5.2]
#  [5.5]
#  [4.9]
#  [5. ]
#  [5.5]
#  [4.9]
#  [4.4]
#  [5.1]
#  [5. ]
#  [4.5]
#  [4.4]
#  [5. ]
#  [5.1]
#  [4.8]
#  [5.1]
#  [4.6]
#  [5.3]
#  [5. ]
#  [7. ]
#  [6.4]
#  [6.9]
#  [5.5]
#  [6.5]
#  [5.7]
#  [6.3]
#  [4.9]
#  [6.6]
#  [5.2]
#  [5. ]
#  [5.9]
#  [6. ]
#  [6.1]
#  [5.6]
#  [6.7]
#  [5.6]
#  [5.8]
#  [6.2]
#  [5.6]
#  [5.9]
#  [6.1]
#  [6.3]
#  [6.1]
#  [6.4]
#  [6.6]
#  [6.8]
#  [6.7]
#  [6. ]
#  [5.7]
#  [5.5]
#  [5.5]
#  [5.8]
#  [6. ]
#  [5.4]
#  [6. ]
#  [6.7]
#  [6.3]
#  [5.6]
#  [5.5]
#  [5.5]
#  [6.1]
#  [5.8]
#  [5. ]
#  [5.6]
#  [5.7]
#  [5.7]
#  [6.2]
#  [5.1]
#  [5.7]
#  [6.3]
#  [5.8]
#  [7.1]
#  [6.3]
#  [6.5]
#  [7.6]
#  [4.9]
#  [7.3]
#  [6.7]
#  [7.2]
#  [6.5]
# ...

# %%
print(y.shape)
# Out:
# (150, 1)

# %%
print(y)
# Out:
# [3.5, 3.0, 3.2, 3.1, 3.6, 3.9, 3.4, 3.4, 2.9, 3.1, 3.7, 3.4, 3.0, 3.0, 4.0, 4.4, 3.9, 3.5, 3.8, 3.8, 3.4, 3.7, 3.6, 3.3, 3.4, 3.0, 3.4, 3.5, 3.4, 3.2, 3.1, 3.4, 4.1, 4.2, 3.1, 3.2, 3.5, 3.6, 3.0, 3.4, 3.5, 2.3, 3.2, 3.5, 3.8, 3.0, 3.8, 3.2, 3.7, 3.3, 3.2, 3.2, 3.1, 2.3, 2.8, 2.8, 3.3, 2.4, 2.9, 2.7, 2.0, 3.0, 2.2, 2.9, 2.9, 3.1, 3.0, 2.7, 2.2, 2.5, 3.2, 2.8, 2.5, 2.8, 2.9, 3.0, 2.8, 3.0, 2.9, 2.6, 2.4, 2.4, 2.7, 2.7, 3.0, 3.4, 3.1, 2.3, 3.0, 2.5, 2.6, 3.0, 2.6, 2.3, 2.7, 3.0, 2.9, 2.9, 2.5, 2.8, 3.3, 2.7, 3.0, 2.9, 3.0, 3.0, 2.5, 2.9, 2.5, 3.6, 3.2, 2.7, 3.0, 2.5, 2.8, 3.2, 3.0, 3.8, 2.6, 2.2, 3.2, 2.8, 2.8, 2.7, 3.3, 3.2, 2.8, 3.0, 2.8, 3.0, 2.8, 3.8, 2.8, 2.8, 2.6, 3.0, 3.4, 3.1, 3.0, 3.1, 3.1, 3.1, 2.7, 3.2, 3.3, 3.0, 2.5, 3.0, 3.4, 3.0]

# %%
area = np.pi*3
# Scatter Plot
plt.scatter(X, y, s=area, alpha=0.5)
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()

# %%
def splitxy(iris):
    X = iris.data[:, :1]  # x is 1st colum -- Sepal Length
    y = iris.data[:, 1:2] # y is 2nd column -- Sepal Width
    return[X,y]

# %%
def mean(values):
    return sum(values)/float(len(values))

# %%
def variance(values, mean):
    return sum((x-mean)**2 for x in values)

# %%
mean_x, mean_y = mean(X), mean(y)
var_x, var_y = variance(X, mean_x), variance(y, mean_y)
print('x stats: mean=%.3f variance=%.3f' % (mean_x, var_x))
print('y stats: mean=%.3f variance=%.3f' % (mean_y, var_y))
# Out:
# x stats: mean=5.843 variance=102.168
# y stats: mean=3.057 variance=28.307

# %% [markdown]
# ## Calculating the Covariance

# %%
def covariance(iris):
    X = iris.data[:, :1]  # x is 1st colum -- Sepal Length
    y = iris.data[:, 1:2] # y is 2nd column -- Sepal Width
    mean_x,mean_y = mean(x),mean(y)
    covariance = 0.0
    for i in range(len(X)):
        covariance += ((x[i]-mean_x) * (y[i]-mean_y))
    return covariance

# %%
mean_x, mean_y = mean(X), mean(y)
var_x, var_y = variance(X, mean_x), variance(y, mean_y)
print('x stats: mean=%.3f variance=%.3f' % (mean_x, var_x))
print('y stats: mean=%.3f variance=%.3f' % (mean_y, var_y))
covar = covariance(iris)
print('Covariance is equal to = %.3f' %covar)
# Out:
# x stats: mean=5.843 variance=102.168
# y stats: mean=3.057 variance=28.307
# Covariance is equal to = -6.323

# %% [markdown]
# ### Covariance unlike Variance can be negative & positive. Positive values signify a substantial correlation and that the variables vary in the same direction. A negative value signifies that the variables vary in opposite directions. Basically it means as the value/amount of variable goes up the other variable goes down. Or as one goes down the other goes up (not directly proportional)

# %% [markdown]
# ## Calculating the Coefficients for Linear Regression

# %%
def coefficients(iris):
    X = iris.data[:, :1]  # x is 1st colum -- Sepal Length
    y = iris.data[:, 1:2] # y is 2nd column -- Sepal Width
    mean_x,mean_y = mean(x),mean(y)
    b1 = covariance(iris) / variance(X,mean_x)
    b0 = (mean(y)-(b1*mean(x)))
    return[b1,b0]

# %%
b1,b0 = coefficients(iris)
print("Coefficients are B1: %.3f & B0: %.3f" %(b0,b1)) ## the coefficients are our weights
# Out:
# Coefficients are B1: 3.419 & B0: -0.062
